# %%
#importing important libraries
#!pip install python-dotenv decorator==4.3 networkx
#!pip install pycoingecko
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import pprint
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %matplotlib inline

# %%
# Set the variables for the Alpaca API and secret keys
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# %%
# Format current date as ISO format
start_date = pd.Timestamp("2019-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2021-06-05", tz="America/New_York").isoformat()

# %%
# Set the tickers
tickers =["TLT","VGLT","VOOG","VMBS","IWF","IGSB","GOVT","AGZ","AAPL","AMZN","CCOI", "PG","BA","NVDA","BRK-A","GS","COP","GILD","BTC","ETH","LTE.V"]

# %%
# Set timeframe to one day ('1D') for the Alpaca API
timeframe = "1D"
data_set= (tickers, timeframe, start_date, end_date)
#set the limit to retrieve
lim = 1000

# %%
# Load .env environment variables
load_dotenv()
# Out:
# True

# %%
# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
# Get portfolio data
portfolio_df = pd.DataFrame()
# Get closing prices of client portfolio from alpaca
portfolio_df = alpaca.get_barset(tickers,timeframe,start = start_date,end = end_date,limit=lim).df
portfolio_df.head()
# Out:
#                              AAPL                                        \
#                              open      high     low     close    volume
# time
# 2019-01-02 05:00:00+00:00  154.89  158.8500  154.23  157.5225  27803621
# 2019-01-03 05:00:00+00:00  143.98  145.7200  142.00  142.2900  82418448
# 2019-01-04 05:00:00+00:00  144.53  148.5499  143.80  148.1200  51267225
# 2019-01-07 05:00:00+00:00  148.70  148.8300  145.90  147.9100  49982480
# 2019-01-08 05:00:00+00:00  149.56  151.8200  148.52  150.6300  36592406
#
#                                 AGZ                                         \
#                                open      high       low     close   volume
# time
# 2019-01-02 05:00:00+00:00  112.2413  112.3100  112.1500  112.2100  24927.0
# 2019-01-03 05:00:00+00:00  112.3244  112.7100  112.2901  112.6800  10395.0
# 2019-01-04 05:00:00+00:00  112.4700  112.4700  112.2601  112.3800  32515.0
# ...

# %% [markdown]
# # portfolio based on risk level

# %% [markdown]
# # Zero risk portfolio

# %%
#Zero risk portfolio: Treasury bonds held to maturity, money market accounts, and CDs where the FDIC guarantees up to $250,000 in losses per person.
#  Treasury bonds(100% )
zero_risk=portfolio_df[["TLT","VGLT","VOOG","VMBS","IWF","IGSB","GOVT","AGZ"]]
zero_risk.dropna()
# Out:
#                                TLT                                         \
#                               open    high       low    close      volume
# time
# 2019-01-02 05:00:00+00:00  121.660  122.15  121.3401  122.150  12607009.0
# 2019-01-03 05:00:00+00:00  122.290  123.86  122.2267  123.535  17221067.0
# 2019-01-04 05:00:00+00:00  122.340  122.56  121.6500  122.210  10034779.0
# 2019-01-07 05:00:00+00:00  122.620  122.65  121.6200  121.765   6743432.0
# 2019-01-08 05:00:00+00:00  121.690  121.94  121.3900  121.405   6932971.0
# ...                            ...     ...       ...      ...         ...
# 2021-05-28 04:00:00+00:00  138.582  139.30  138.3400  138.340   9346538.0
# 2021-06-01 04:00:00+00:00  137.820  138.26  137.2500  138.220   9842975.0
# 2021-06-02 04:00:00+00:00  138.540  138.79  138.3200  138.510   5597133.0
# 2021-06-03 04:00:00+00:00  138.510  138.51  137.8450  138.002   9221502.0
# 2021-06-04 04:00:00+00:00  138.520  139.89  138.5200  139.885  13573285.0
#
# ...

# %% [markdown]
# # Lower Risk portfolio (80% bonds and 20% stocks)

# %%
#Lower Risk portfolio (80% bonds and 20% stocks)
lower_risk_portfolio = portfolio_df[["TLT","VGLT","VOOG","VMBS","IWF","IGSB","GOVT","AGZ","AAPL","AMZN"]]
lower_risk_portfolio.dropna()
# Out:
#                                TLT                                         \
#                               open    high       low    close      volume
# time
# 2019-01-02 05:00:00+00:00  121.660  122.15  121.3401  122.150  12607009.0
# 2019-01-03 05:00:00+00:00  122.290  123.86  122.2267  123.535  17221067.0
# 2019-01-04 05:00:00+00:00  122.340  122.56  121.6500  122.210  10034779.0
# 2019-01-07 05:00:00+00:00  122.620  122.65  121.6200  121.765   6743432.0
# 2019-01-08 05:00:00+00:00  121.690  121.94  121.3900  121.405   6932971.0
# ...                            ...     ...       ...      ...         ...
# 2021-05-28 04:00:00+00:00  138.582  139.30  138.3400  138.340   9346538.0
# 2021-06-01 04:00:00+00:00  137.820  138.26  137.2500  138.220   9842975.0
# 2021-06-02 04:00:00+00:00  138.540  138.79  138.3200  138.510   5597133.0
# 2021-06-03 04:00:00+00:00  138.510  138.51  137.8450  138.002   9221502.0
# 2021-06-04 04:00:00+00:00  138.520  139.89  138.5200  139.885  13573285.0
#
# ...

# %% [markdown]
# # Low Medium Risk portfolio(60% bonds and 40% stocks)

# %%
low_medium_risk_portfolio=portfolio_df[["TLT","VGLT","VOOG","VMBS","IWF","IGSB","AAPL","AMZN","BA","NVDA"]]
low_medium_risk_portfolio.dropna()
# Out:
#                                TLT                                         \
#                               open    high       low    close      volume
# time
# 2019-01-02 05:00:00+00:00  121.660  122.15  121.3401  122.150  12607009.0
# 2019-01-03 05:00:00+00:00  122.290  123.86  122.2267  123.535  17221067.0
# 2019-01-04 05:00:00+00:00  122.340  122.56  121.6500  122.210  10034779.0
# 2019-01-07 05:00:00+00:00  122.620  122.65  121.6200  121.765   6743432.0
# 2019-01-08 05:00:00+00:00  121.690  121.94  121.3900  121.405   6932971.0
# ...                            ...     ...       ...      ...         ...
# 2021-05-28 04:00:00+00:00  138.582  139.30  138.3400  138.340   9346538.0
# 2021-06-01 04:00:00+00:00  137.820  138.26  137.2500  138.220   9842975.0
# 2021-06-02 04:00:00+00:00  138.540  138.79  138.3200  138.510   5597133.0
# 2021-06-03 04:00:00+00:00  138.510  138.51  137.8450  138.002   9221502.0
# 2021-06-04 04:00:00+00:00  138.520  139.89  138.5200  139.885  13573285.0
#
# ...

# %% [markdown]
# # Medium Risk Portfolio (60% stocks and 40% bonds)

# %%
medium_risk_portfolio= portfolio_df[["TLT","VGLT","VOOG","VMBS","AAPL","AMZN","BA","NVDA","GS"]]
medium_risk_portfolio.dropna()
# Out:
#                                TLT                                         \
#                               open    high       low    close      volume
# time
# 2019-01-02 05:00:00+00:00  121.660  122.15  121.3401  122.150  12607009.0
# 2019-01-03 05:00:00+00:00  122.290  123.86  122.2267  123.535  17221067.0
# 2019-01-04 05:00:00+00:00  122.340  122.56  121.6500  122.210  10034779.0
# 2019-01-07 05:00:00+00:00  122.620  122.65  121.6200  121.765   6743432.0
# 2019-01-08 05:00:00+00:00  121.690  121.94  121.3900  121.405   6932971.0
# ...                            ...     ...       ...      ...         ...
# 2021-05-28 04:00:00+00:00  138.582  139.30  138.3400  138.340   9346538.0
# 2021-06-01 04:00:00+00:00  137.820  138.26  137.2500  138.220   9842975.0
# 2021-06-02 04:00:00+00:00  138.540  138.79  138.3200  138.510   5597133.0
# 2021-06-03 04:00:00+00:00  138.510  138.51  137.8450  138.002   9221502.0
# 2021-06-04 04:00:00+00:00  138.520  139.89  138.5200  139.885  13573285.0
#
# ...

# %% [markdown]
# # Medium High Risk portfolio(70% stocks and 30% bonds)

# %%
medium_high_risk_portfolio = portfolio_df[["AAPL","AMZN", "BA","NVDA","BRK-A","GS","COP","TLT","VGLT","VOOG"]]
medium_high_risk_portfolio
# Out:
#                              AAPL                                        \
#                              open      high     low     close    volume
# time
# 2019-01-02 05:00:00+00:00  154.89  158.8500  154.23  157.5225  27803621
# 2019-01-03 05:00:00+00:00  143.98  145.7200  142.00  142.2900  82418448
# 2019-01-04 05:00:00+00:00  144.53  148.5499  143.80  148.1200  51267225
# 2019-01-07 05:00:00+00:00  148.70  148.8300  145.90  147.9100  49982480
# 2019-01-08 05:00:00+00:00  149.56  151.8200  148.52  150.6300  36592406
# ...                           ...       ...     ...       ...       ...
# 2021-05-28 04:00:00+00:00  125.57  125.8000  124.55  124.6200  61946057
# 2021-06-01 04:00:00+00:00  125.07  125.3500  123.94  124.3000  58891765
# 2021-06-02 04:00:00+00:00  124.29  125.2400  124.05  125.0900  51393692
# 2021-06-03 04:00:00+00:00  124.66  124.8500  123.13  123.5550  68331470
# 2021-06-04 04:00:00+00:00  124.07  126.1600  123.85  125.8800  63613126
#
# ...
